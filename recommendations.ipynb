# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
# Out:
# /Users/bassim/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
data = pd.read_csv('final_output.csv',index_col='Unnamed: 0')

# %%
data.head(2)
# Out:
#                              benefits                         unique_configs  \
# 0                                 NaN  This is a non-text non-numeric answer
# 1  common accident deductible applies  This is a non-text non-numeric answer
#
#   all_configs                                         covg_codes  \
# 0        none  ['JNN', 'A3F', 'O6P', 'BDQ', 'DYY', 'ASF', 'B6...
# 1        none  ['NIT', 'BDT', 'MIU', 'A3F', 'O6P', 'BDQ', '0I...
#
#                                              ans_tag    type_tag  num_config  \
# 0  ['RSMANOUT', 'CNWCCYRS', 'RSIDOSYD', 'RNDEPCVO...  ['C', 'R']           0
# 1                                       ['RSCOMACY']       ['R']           0
#
#    mean_expo_score  mean_claim_score  top_50_count  top_50_ratio  \
# 0             5.25              8.63         12166          0.19
# 1             5.47              8.96           232          0.28
#
#    num_cov_codes
# 0           2736
# 1            767

# %%
# sort by benefits
data.sort_values(by='benefits')

# sort by top_50 clients
data.sort_values(by=['top_50_count'],ascending=False)
data.sort_values(by=['top_50_ratio'],ascending=False)

# sort by num_configs
data.sort_values(by='num_config',ascending=False)

# sort by mean_expo_score or mean_claim_score or num_cov_codes for popular benefits
data.sort_values(by=['mean_expo_score','mean_claim_score'],ascending=False)
data.sort_values(by=['num_cov_codes'],ascending=False)

# rows/benefits that need language standardization
data[data['unique_configs']=="[[]]"]
# Out:
#                                                benefits unique_configs  \
# 17    an eligible dependent student is unmarried and...           [[]]
# 47    late enrollees (a member who is not a new hire...           [[]]
# 81    management, consultation, counseling, and surg...           [[]]
# 124   an eligible child is married or unmarried and ...           [[]]
# 154   late enrollees (a member who is not a new hire...           [[]]
# 189   an eligible disabled dependent child is unmarr...           [[]]
# 211                           age 7 through 13 $ 25,000           [[]]
# 216   refractive surgery covered with a prior approv...           [[]]
# 224   an eligible dependent student is unmarried and...           [[]]
# 241                 wigs are covered after chemotherapy           [[]]
# 271                               orthotics are covered           [[]]
# 291   an eligible child is married or unmarried and ...           [[]]
# ...
