# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling

# %%
df = pd.read_csv('h1b2018.csv')
# Out:
# /Users/bassim/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#           case_number visa_class case_status  \
# 0  I-200-18178-159595       H-1B   CERTIFIED
# 1  I-200-18107-532650       H-1B   CERTIFIED
# 2  I-200-18183-381518       H-1B   CERTIFIED
# 3  I-200-18149-760149       H-1B   CERTIFIED
# 4  I-200-18222-447165       H-1B   CERTIFIED
#
#                        employer_name employer_business_dba  \
# 0            DELOITTE CONSULTING LLP                   NaN
# 1                     METASENSE INC.                   NaN
# 2      DFG INVESTMENT ADVISERS, INC.                   NaN
# 3  TATA CONSULTANCY SERVICES LIMITED                   NaN
# 4                   I3 INFOTEK, INC.                   NaN
#
#            employer_address employer_city employer_state employer_postal_code  \
# 0        1700 MARKET STREET  PHILADELPHIA             PA                19103
# 1         403 COMMERCE LANE   WEST BERLIN             NJ                08091
# 2          747 THIRD AVENUE      NEW YORK             NY                10017
# ...

# %%
df.columns
# Out:
# Index(['case_number', 'visa_class', 'case_status', 'employer_name',
#        'employer_business_dba', 'employer_address', 'employer_city',
#        'employer_state', 'employer_postal_code', 'employer_country',
#        'employer_province', 'employer_phone', 'employer_phone_ext',
#        'naics_code', 'soc_code', 'soc_name', 'job_title', 'total_workers',
#        'case_submitted', 'decision_date', 'employment_start_date',
#        'employment_end_date', 'full_time_position', 'prevailing_wage',
#        'pw_unit_of_pay', 'wage_rate_of_pay_from', 'wage_rate_of_pay_to',
#        'wage_unit_of_pay', 'worksite_city', 'worksite_county',
#        'worksite_state', 'worksite_postal_code', 'agent_attorney_name',
#        'agent_representing_employer', 'agent_attorney_city',
#        'agent_attorney_state', 'h1b_dependent', 'willful_violator',
#        'original_cert_date', 'new_employment', 'continued_employment',
#        'change_previous_employment', 'new_concurrent_employment',
# ...

# %%
df.shape
# Out:
# (654360, 52)

# %%
pandas_profiling.ProfileReport(df[['visa_class','employer_name','employer_address','employer_city','employer_state','employer_province','prevailing_wage','job_title','full_time_position','pw_unit_of_pay']])
# Out:
# /Users/bassim/anaconda3/lib/python3.6/site-packages/pandas_profiling/describe.py:404: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
# ...
